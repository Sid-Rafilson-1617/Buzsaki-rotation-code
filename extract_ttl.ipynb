# %% [markdown]
# ### This code extracts the TTL times from the OneBox data streaming

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from ipywidgets import interact

# %%
def read_meta(meta_path):
    meta = {}
    with open(meta_path, 'r') as f:
        for line in f:
            line = line.strip()
            if not line or line.startswith('~'):
                continue
            if '=' in line:
                k, v = line.split('=', 1)
                meta[k] = v
    # Cast the fields we care about
    meta['nSavedChans'] = int(meta['nSavedChans'])
    meta['obSampRate'] = float(meta['obSampRate'])
    return meta

def load_obx_channel(bin_path, meta_path, chan_idx):
    meta = read_meta(meta_path)
    n_ch = meta['nSavedChans']
    fs = meta['obSampRate']

    # int16, little-endian (SpikeGLX / CatGT standard)
    raw = np.memmap(bin_path, dtype='<i2', mode='r')
    n_samples = raw.size // n_ch
    data = raw.reshape((n_samples, n_ch))

    ttl = data[:, chan_idx]
    return ttl, fs

def find_ttl_rising_edges(ttl, fs, threshold=None, min_interval=0.001):
    """
    ttl: 1D np.array of int16 or float
    fs:  sampling rate (Hz)
    threshold: value to define 'high' vs 'low'. If None, auto-estimate.
    min_interval: min time (s) between distinct TTL pulses (to de-bounce).
    """
    ttl = np.asarray(ttl)

    # Auto threshold: mid-point between low and high clusters
    if threshold is None:
        lo = np.percentile(ttl, 5)
        hi = np.percentile(ttl, 95)
        threshold = (lo + hi) / 2.0

    above = ttl >= threshold
    # Rising edges: was below, now above
    rising = np.where(~above[:-1] & above[1:])[0] + 1

    # Optional de-bounce: enforce minimum spacing between pulses
    if min_interval is not None and rising.size > 0:
        min_samples = int(min_interval * fs)
        keep = [rising[0]]
        for idx in rising[1:]:
            if idx - keep[-1] >= min_samples:
                keep.append(idx)
        rising = np.array(keep, dtype=int)

    times_sec = rising / fs
    return rising, times_sec, threshold

# %% [markdown]
# ### Manual extraction of rising times on the TTL pulses

# %%
bin_path = r"\\research-cifs.nyumc.org\research\buzsakilab\Homes\voerom01\Bilat_HPC\Bilat_R02\Bilat_R02_20251106\preprocessing_output\supercat_pre_sleep_g0\pre_sleep_g0_tcat.obx0.obx.bin"
meta_path = r"\\research-cifs.nyumc.org\research\buzsakilab\Homes\voerom01\Bilat_HPC\Bilat_R02\Bilat_R02_20251106\preprocessing_output\supercat_pre_sleep_g0\pre_sleep_g0_tcat.obx0.obx.meta"

ttl, fs = load_obx_channel(bin_path, meta_path, chan_idx=6)
print(f'TTL shape: {ttl.shape}, FS: {fs}')

rising_samples, rising_times, thr = find_ttl_rising_edges(ttl, fs)

print(f"Detected {len(rising_samples)} TTL pulses")
print("First 10 times (s):", rising_times[:10])
print("last 10 times (s):", rising_times[-10:])
print("Used threshold:", thr)


csv_path = r"\\research-cifs.nyumc.org\research\buzsakilab\Homes\voerom01\Bilat_HPC\Bilat_R02\Bilat_R02_20251106\manual_ttl_extraction.csv"
df = pd.DataFrame({'ttl_times_sec': rising_times, 'ttl_samples': rising_samples})
df.to_csv(csv_path, index=False)
# Out:
# TTL shape: (318820441,), FS: 30303.03025210084
# Detected 308285 TTL pulses
# First 10 times (s): [3926.3532066 3926.3615556 3926.3698716 3926.3782206 3926.3865366
#  3926.3948856 3926.4032016 3926.4115506 3926.4198996 3926.4282156]
# last 10 times (s): [6495.18039492 6495.18874392 6495.19705992 6495.20540892 6495.21372492
#  6495.22207392 6495.23038992 6495.23873892 6495.24705492 6495.25540392]
# Used threshold: 10429.0

# %%
#plot distribution of inter-ttl intervals
intervals = np.diff(rising_times)
plt.figure(figsize=(8,4))
plt.hist(intervals, bins=100, color='blue', alpha=0.7)
plt.title('Distribution of Inter-TTL Intervals')
plt.xlabel('Interval (s)')
plt.ylabel('Count')
plt.show()

# %%
def plot_ttl_segment(start=0, duration=10):
    end = start + duration
    start_idx = int(start * fs)
    end_idx = int(end * fs)
    
    plt.figure(figsize=(20,4))
    sns.lineplot(x=np.arange(start_idx, end_idx)/fs, y=ttl[start_idx:end_idx])
    sns.scatterplot(x=rising_times[(rising_times >= start) & (rising_times < end)], 
                    y=ttl[rising_samples][(rising_times >= start) & (rising_times < end)], 
                    color='red', s=50, label='Rising Edges')

    plt.title(f'TTL Signal from {start}s to {end}s')
    plt.xlabel('Time (s)')
    plt.ylabel('TTL Value')
    plt.show()

interact(plot_ttl_segment, start=(0, (len(ttl) / fs) - 10, 1), duration=(0.1, 5, 0.05))
# Out:
# interactive(children=(FloatSlider(value=0.0, description='start', max=10511.074570682478, step=1.0), FloatSlid…
# <function __main__.plot_ttl_segment(start=0, duration=10)>

# %% [markdown]
# ### Loading the CatGT extracted TTL times

# %%
# extract ttl times from CatGT output file
obx_file = r'R:\Bilat_HPC\Bilat_R02\Bilat_R02_20251106\preprocessing_output\supercat_pre_sleep_g0\pre_sleep_g0_tcat.obx0.obx.xd_6_12_0.adj.txt'
ttl_times = np.loadtxt(obx_file)

bad_ttl_indices = [0]
ttls = np.delete(ttl_times, bad_ttl_indices)

#print first 10 ttls
print("First 10 TTL times after removing bad indices:", ttls[:10])
print("last 10 TTL times after removing bad indices:", ttls[-10:])

print(f"Number of TTLs after removing bad indices: {len(ttls)}")
plt.figure()
sns.histplot(np.diff(ttls), bins=100)
plt.show()
# Out:
# First 10 TTL times after removing bad indices: [3926.312133 3926.328798 3926.345463 3926.357805 3926.362128 3926.37447
#  3926.378793 3926.395458 3926.4078   3926.412123]
# last 10 TTL times after removing bad indices: [6495.050291 6495.066956 6495.083621 6495.095963 6495.100286 6495.116951
#  6495.133616 6495.137642 6495.154307 6495.170972]
# Number of TTLs after removing bad indices: 240195

# %%
print(fs)

def plot_ttl_scatter(start=0, duration = 10):
    end = start + duration
    start_idx = int(start * fs)
    end_idx = int(end * fs)

    plt.figure(figsize=(20,4))
    sns.scatterplot(x=ttls[start_idx:end_idx], y=np.ones_like(ttls[start_idx:end_idx]), color='blue', s=5)
    plt.title(f'TTL Times from {start}s to {end}s')
    plt.xlabel('Time (s)')
    plt.ylabel('TTL Time (s)')
    plt.show()

interact(plot_ttl_scatter, start=(0, (len(ttls) / fs) - 10, 1), duration=(0.001, 1, 0.001))
# Out:
# 30303.03025210084
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[29], line 15
#      12     plt.ylabel('TTL Time (s)')
#      13     plt.show()
# ---> 15 interact(plot_ttl_scatter, start=(0, (len(ttls) / fs) - 10, 1), duration=(0.001, 1, 0.001))
#
# File c:\Users\Buzlab\anaconda3\Lib\site-packages\ipywidgets\widgets\interaction.py:529, in _InteractFactory.__call__(self, _InteractFactory__interact_f, **kwargs)
#     521     return self
#     523 # positional arg support in: https://gist.github.com/8851331
#     524 # Handle the cases 1 and 2
#     525 # 1. interact(f, **kwargs)
#     526 # 2. @interact
#     527 #    def f(*args, **kwargs):
#     528 #        ...
# --> 529 w = self.widget(f)
#     530 try:
#     531     f.widget = w
#
# File c:\Users\Buzlab\anaconda3\Lib\site-packages\ipywidgets\widgets\interaction.py:445, in _InteractFactory.widget(self, f)
# ...
